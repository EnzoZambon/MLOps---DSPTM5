# %%
from Cargar_datos import cargar_datos
import pandas as pd
import matplotlib.pyplot as plt

df = cargar_datos()
df.head()
# Out:
# Leyendo archivo desde: C:\Users\Enzo\OneDrive\Escritorio\Data Science Henry\Modulo 5\MLOps---DSPTM5\Base_de_datos.xlsx
#    tipo_credito      fecha_prestamo  capital_prestado  plazo_meses  \
# 0             7 2024-12-21 11:31:35         3692160.0           10
# 1             4 2025-04-22 09:47:35          840000.0            6
# 2             9 2026-01-08 12:22:40         5974028.4           10
# 3             4 2025-08-04 12:04:10         1671240.0            6
# 4             9 2025-04-26 11:24:26         2781636.0           11
#
#    edad_cliente   tipo_laboral  salario_cliente  total_otros_prestamos  \
# 0            42  Independiente          8000000                2500000
# 1            60       Empleado          3000000                2000000
# 2            36  Independiente          4036000                 829000
# 3            48       Empleado          1524547                 498000
# 4            44       Empleado          5000000                4000000
#
#    cuota_pactada    puntaje  ...  saldo_mora  saldo_total  saldo_principal  \
# 0         341296  88.768094  ...         0.0      51258.0          51258.0
# 1         124876  95.227787  ...         0.0       8673.0           8673.0
# 2         529554  47.613894  ...         0.0      18702.0          18702.0
# 3         252420  95.227787  ...         0.0      15782.0          15782.0
# 4         217037  95.227787  ...         0.0     204804.0         204804.0
#
#    saldo_mora_codeudor  creditos_sectorFinanciero  creditos_sectorCooperativo  \
# 0                  0.0                          5                           0
# 1                  0.0                          0                           0
# 2                  0.0                          3                           0
# 3                  0.0                          3                           0
# 4                  0.0                          3                           0
#
#    creditos_sectorReal  promedio_ingresos_datacredito  tendencia_ingresos  \
# 0                    0                       908526.0             Estable
# 1                    2                       939017.0           Creciente
# 2                    0                            NaN                 NaN
# 3                    0                      1536193.0           Creciente
# 4                    1                       933473.0           Creciente
#
#    Pago_atiempo
# 0             1
# 1             1
# 2             0
# 3             1
# 4             1
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (10763, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10763 entries, 0 to 10762
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   tipo_credito                   10763 non-null  int64
#  1   fecha_prestamo                 10763 non-null  datetime64[ns]
#  2   capital_prestado               10763 non-null  float64
#  3   plazo_meses                    10763 non-null  int64
#  4   edad_cliente                   10763 non-null  int64
#  5   tipo_laboral                   10763 non-null  object
#  6   salario_cliente                10763 non-null  int64
#  7   total_otros_prestamos          10763 non-null  int64
#  8   cuota_pactada                  10763 non-null  int64
#  9   puntaje                        10763 non-null  float64
#  10  puntaje_datacredito            10757 non-null  float64
#  11  cant_creditosvigentes          10763 non-null  int64
#  12  huella_consulta                10763 non-null  int64
#  13  saldo_mora                     10607 non-null  float64
#  14  saldo_total                    10607 non-null  float64
#  15  saldo_principal                10358 non-null  float64
#  16  saldo_mora_codeudor            10173 non-null  float64
#  17  creditos_sectorFinanciero      10763 non-null  int64
#  18  creditos_sectorCooperativo     10763 non-null  int64
#  19  creditos_sectorReal            10763 non-null  int64
#  20  promedio_ingresos_datacredito  7833 non-null   float64
#  21  tendencia_ingresos             7831 non-null   object
#  22  Pago_atiempo                   10763 non-null  int64
# dtypes: datetime64[ns](1), float64(8), int64(12), object(2)
# memory usage: 1.9+ MB

# %%
df.describe()
# Out:
#        tipo_credito                 fecha_prestamo  capital_prestado  \
# count  10763.000000                          10763      1.076300e+04
# mean       5.411131  2025-04-16 23:06:02.111121664      2.434315e+06
# min        4.000000            2024-11-26 09:17:04      3.600000e+05
# 25%        4.000000     2025-01-20 17:33:07.500000      1.224831e+06
# 50%        4.000000            2025-03-27 16:23:12      1.921920e+06
# 75%        9.000000            2025-06-16 13:27:58      3.084840e+06
# max       68.000000            2026-04-26 18:43:52      4.144415e+07
# std        2.338279                            NaN      1.909643e+06
#
#         plazo_meses  edad_cliente  salario_cliente  total_otros_prestamos  \
# count  10763.000000  10763.000000     1.076300e+04           1.076300e+04
# mean      10.575583     43.948620     1.721643e+07           6.238870e+06
# min        2.000000     19.000000     0.000000e+00           0.000000e+00
# 25%        6.000000     33.000000     2.000000e+06           5.000000e+05
# 50%       10.000000     42.000000     3.000000e+06           1.000000e+06
# 75%       12.000000     53.000000     4.875808e+06           2.000000e+06
# max       90.000000    123.000000     2.200000e+10           6.787675e+09
# std        6.632082     15.060877     3.554767e+08           1.184183e+08
#
#        cuota_pactada       puntaje  puntaje_datacredito  ...  huella_consulta  \
# count   1.076300e+04  10763.000000         10757.000000  ...     10763.000000
# mean    2.436174e+05     91.170036           780.790834  ...         4.228561
# min     2.394400e+04    -38.009990            -7.000000  ...         0.000000
# 25%     1.210415e+05     95.227787           757.000000  ...         2.000000
# 50%     1.828630e+05     95.227787           791.000000  ...         4.000000
# 75%     2.878335e+05     95.227787           825.000000  ...         6.000000
# max     3.816752e+06     95.227787           999.000000  ...        29.000000
# std     2.104937e+05     16.465441           104.878031  ...         3.064683
#
#          saldo_mora   saldo_total  saldo_principal  saldo_mora_codeudor  \
# count  10607.000000  1.060700e+04     1.035800e+04         10173.000000
# mean       7.746017  4.593741e+04     4.034617e+04             0.260002
# min        0.000000  0.000000e+00     0.000000e+00             0.000000
# 25%        0.000000  2.898000e+03     2.690000e+03             0.000000
# 50%        0.000000  1.617800e+04     1.444250e+04             0.000000
# 75%        0.000000  5.298200e+04     4.763225e+04             0.000000
# max    12534.000000  5.116066e+06     1.562285e+06          2145.000000
# std      225.955117  1.062698e+05     7.124244e+04            21.772917
#
#        creditos_sectorFinanciero  creditos_sectorCooperativo  \
# count               10763.000000                10763.000000
# mean                    2.779987                    0.269813
# min                     0.000000                    0.000000
# 25%                     1.000000                    0.000000
# 50%                     2.000000                    0.000000
# 75%                     4.000000                    0.000000
# max                    51.000000                   13.000000
# std                     2.748807                    0.716471
#
#        creditos_sectorReal  promedio_ingresos_datacredito  Pago_atiempo
# count         10763.000000                   7.833000e+03  10763.000000
# mean              1.302704                   2.005157e+06      0.952523
# min               0.000000                   0.000000e+00      0.000000
# 25%               0.000000                   9.251570e+05      1.000000
# 50%               1.000000                   1.204496e+06      1.000000
# 75%               2.000000                   2.231859e+06      1.000000
# max              25.000000                   3.810658e+07      1.000000
# std               1.824430                   2.144116e+06      0.212668
#
# [8 rows x 21 columns]

# %%
df.describe(include="object")
# Out:
#        tipo_laboral tendencia_ingresos
# count         10763               7831
# unique            2                 46
# top        Empleado          Creciente
# freq           6754               5294

# %%
df.isnull().sum()
# Out:
# tipo_credito                        0
# fecha_prestamo                      0
# capital_prestado                    0
# plazo_meses                         0
# edad_cliente                        0
# tipo_laboral                        0
# salario_cliente                     0
# total_otros_prestamos               0
# cuota_pactada                       0
# puntaje                             0
# puntaje_datacredito                 6
# cant_creditosvigentes               0
# huella_consulta                     0
# saldo_mora                        156
# saldo_total                       156
# saldo_principal                   405
# saldo_mora_codeudor               590
# creditos_sectorFinanciero           0
# creditos_sectorCooperativo          0
# creditos_sectorReal                 0
# promedio_ingresos_datacredito    2930
# tendencia_ingresos               2932
# Pago_atiempo                        0
# dtype: int64

# %%
######## TRATAMIENTO DE NULOS ########

#1. saldo_mora: 0 porque es probable que no tenga mora si no hay dato
df["saldo_mora"] = df["saldo_mora"].fillna(0)

#2. saldo_mora_codeudor: 0 porque es probable que no tenga mora si no hay dato
df["saldo_mora_codeudor"] = df["saldo_mora_codeudor"].fillna(0)

#3. saldo_principal: mediana porque es menos sensible a outliers
df["saldo_principal"] = df["saldo_principal"].fillna(df["saldo_principal"].median())


#4. saldo_total: saldo_principal + saldo_mora porque es la suma de ambos
df["saldo_total"] = df["saldo_total"].fillna(
    df["saldo_principal"] + df["saldo_mora"])


#5. promedio_ingresos_datacredito: mediana porque es menos sensible a outliers
df["promedio_ingresos_datacredito"] = df["promedio_ingresos_datacredito"].fillna(
    df["promedio_ingresos_datacredito"].median())

#6. tendencia_ingresos: moda porque es la categoría más común
df["tendencia_ingresos"] = df["tendencia_ingresos"].fillna(
    df["tendencia_ingresos"].mode()[0])

# %%
df.isnull().sum()
# Out:
# tipo_credito                     0
# fecha_prestamo                   0
# capital_prestado                 0
# plazo_meses                      0
# edad_cliente                     0
# tipo_laboral                     0
# salario_cliente                  0
# total_otros_prestamos            0
# cuota_pactada                    0
# puntaje                          0
# puntaje_datacredito              6
# cant_creditosvigentes            0
# huella_consulta                  0
# saldo_mora                       0
# saldo_total                      0
# saldo_principal                  0
# saldo_mora_codeudor              0
# creditos_sectorFinanciero        0
# creditos_sectorCooperativo       0
# creditos_sectorReal              0
# promedio_ingresos_datacredito    0
# tendencia_ingresos               0
# Pago_atiempo                     0
# dtype: int64

# %% [markdown]
# ANÁLISIS UNIVARIABLE

# %% [markdown]
# 1. TIPO DE CREDITO

# %%
df["tipo_credito"].value_counts().sort_index()
# Out:
# tipo_credito
# 4     7747
# 6       21
# 7        2
# 9     2876
# 10     116
# 68       1
# Name: count, dtype: int64

# %%
print(df["tipo_credito"].value_counts().sort_index())

plt.figure(figsize=(6,4))
plt.boxplot(df["tipo_credito"].dropna())
plt.title("Outliers - tipo_credito")
plt.show()
# Out:
# tipo_credito
# 4     7747
# 6       21
# 7        2
# 9     2876
# 10     116
# 68       1
# Name: count, dtype: int64

# %%
cols = [
    "tipo_credito",
    "plazo_meses",
    "edad_cliente",
    "tipo_laboral",
    "cant_creditosvigentes",
    "huella_consulta",
    "creditos_sectorFinanciero",
    "creditos_sectorCooperativo",
    "creditos_sectorReal",
]

for col in cols:
    plt.figure(figsize=(8,4))

    # Conteo de frecuencias (sin fijar rango)
    freq = df[col].dropna().value_counts().sort_index()

    # Si la variable es categórica (texto), reindexamos para que no queden etiquetas amontonadas
    if df[col].dtype == "object":
        plt.bar(range(len(freq)), freq.values)
        plt.xticks(range(len(freq)), freq.index, rotation=45, ha="right")
        plt.xlabel(col)
    else:
        # Si es numérica, usamos directamente los valores en el eje X
        plt.bar(freq.index, freq.values)
        plt.xlabel(col)

    plt.title(f"Distribución de {col}")
    plt.ylabel("Frecuencia")
    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt

df["capital_prestado"].hist(bins=30)
plt.title("Distribución del Capital Prestado")
plt.show()

# %%
import matplotlib.pyplot as plt

hist_cols = [
    "capital_prestado",
    "salario_cliente",
    "cuota_pactada",
    "saldo_mora",
    "saldo_total"
]

for col in hist_cols:
    plt.figure(figsize=(7,4))
    
    df[col].dropna().hist()   # quitamos nulos solo para graficar
    
    plt.title(f"Histograma de {col}")
    plt.xlabel(col)
    plt.ylabel("Frecuencia")
    
    plt.tight_layout()
    plt.show()

# %%
(df["saldo_mora"] > 0).mean() * 100
# Out:
# np.float64(0.511009941466134)

# %% [markdown]
# ANALISIS BIVARIABLES

# %%
pd.crosstab(df["tipo_credito"], df["Pago_atiempo"], normalize="index") * 100
# Out:
# Pago_atiempo          0           1
# tipo_credito
# 4              4.685685   95.314315
# 6             42.857143   57.142857
# 7              0.000000  100.000000
# 9              4.728790   95.271210
# 10             2.586207   97.413793
# 68             0.000000  100.000000

# %%
pd.crosstab(df["tipo_credito"], df["Pago_atiempo"]).plot(kind="bar", figsize=(8,5))
plt.title("Tipo de crédito vs Pago a tiempo")
plt.show()

# %%
num_cols = [
    "capital_prestado",
    "salario_cliente",
    "cuota_pactada",
    "saldo_mora",
    "saldo_total",
    "saldo_principal",
    "promedio_ingresos_datacredito",
    "creditos_sectorFinanciero",
    "creditos_sectorCooperativo",
    "creditos_sectorReal"
]

df[num_cols].corr().round(2)
# Out:
#                                capital_prestado  salario_cliente  \
# capital_prestado                           1.00             0.05
# salario_cliente                            0.05             1.00
# cuota_pactada                              0.76             0.05
# saldo_mora                                 0.02             0.00
# saldo_total                                0.12            -0.00
# saldo_principal                            0.15            -0.00
# promedio_ingresos_datacredito              0.10            -0.01
# creditos_sectorFinanciero                  0.11            -0.02
# creditos_sectorCooperativo                -0.02            -0.01
# creditos_sectorReal                       -0.08            -0.03
#
#                                cuota_pactada  saldo_mora  saldo_total  \
# capital_prestado                        0.76        0.02         0.12
# salario_cliente                         0.05        0.00        -0.00
# cuota_pactada                           1.00        0.00         0.13
# saldo_mora                              0.00        1.00         0.00
# saldo_total                             0.13        0.00         1.00
# saldo_principal                         0.18        0.01         0.74
# promedio_ingresos_datacredito           0.07       -0.00         0.21
# creditos_sectorFinanciero               0.11        0.01         0.45
# creditos_sectorCooperativo             -0.03        0.00         0.09
# creditos_sectorReal                    -0.07        0.00         0.07
#
#                                saldo_principal  promedio_ingresos_datacredito  \
# capital_prestado                          0.15                           0.10
# salario_cliente                          -0.00                          -0.01
# cuota_pactada                             0.18                           0.07
# saldo_mora                                0.01                          -0.00
# saldo_total                               0.74                           0.21
# saldo_principal                           1.00                           0.27
# promedio_ingresos_datacredito             0.27                           1.00
# creditos_sectorFinanciero                 0.54                           0.22
# creditos_sectorCooperativo                0.09                           0.01
# creditos_sectorReal                       0.09                          -0.04
#
#                                creditos_sectorFinanciero  \
# capital_prestado                                    0.11
# salario_cliente                                    -0.02
# cuota_pactada                                       0.11
# saldo_mora                                          0.01
# saldo_total                                         0.45
# saldo_principal                                     0.54
# promedio_ingresos_datacredito                       0.22
# creditos_sectorFinanciero                           1.00
# creditos_sectorCooperativo                         -0.02
# creditos_sectorReal                                 0.07
#
#                                creditos_sectorCooperativo  creditos_sectorReal
# capital_prestado                                    -0.02                -0.08
# salario_cliente                                     -0.01                -0.03
# cuota_pactada                                       -0.03                -0.07
# saldo_mora                                           0.00                 0.00
# saldo_total                                          0.09                 0.07
# saldo_principal                                      0.09                 0.09
# promedio_ingresos_datacredito                        0.01                -0.04
# creditos_sectorFinanciero                           -0.02                 0.07
# creditos_sectorCooperativo                           1.00                 0.06
# creditos_sectorReal                                  0.06                 1.00

# %%
plt.figure(figsize=(6,4))
plt.scatter(df["promedio_ingresos_datacredito"], df["saldo_total"], alpha=0.5)
plt.xlabel("Ingresos promedio")
plt.ylabel("Saldo total")
plt.title("Ingresos vs Saldo total")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.scatter(df["capital_prestado"], df["cuota_pactada"], alpha=0.5)
plt.xlabel("Capital prestado")
plt.ylabel("Cuota pactada")
plt.title("Capital vs Cuota")
plt.show()

# %% [markdown]
# ANALISIS MULTIVARIABLE

# %%
df_mv = df[[
"saldo_total",
"saldo_principal",
"saldo_mora_codeudor",
"creditos_sectorFinanciero",
"creditos_sectorCooperativo",
"creditos_sectorReal",
"promedio_ingresos_datacredito",
"Pago_atiempo"
]].copy()

# %%
corr_matrix = df_mv.corr().round(2)
corr_matrix
# Out:
#                                saldo_total  saldo_principal  \
# saldo_total                           1.00             0.74
# saldo_principal                       0.74             1.00
# saldo_mora_codeudor                  -0.00            -0.01
# creditos_sectorFinanciero             0.45             0.54
# creditos_sectorCooperativo            0.09             0.09
# creditos_sectorReal                   0.07             0.09
# promedio_ingresos_datacredito         0.21             0.27
# Pago_atiempo                          0.01             0.01
#
#                                saldo_mora_codeudor  creditos_sectorFinanciero  \
# saldo_total                                  -0.00                       0.45
# saldo_principal                              -0.01                       0.54
# saldo_mora_codeudor                           1.00                      -0.01
# creditos_sectorFinanciero                    -0.01                       1.00
# creditos_sectorCooperativo                   -0.00                      -0.02
# creditos_sectorReal                          -0.00                       0.07
# promedio_ingresos_datacredito                -0.00                       0.22
# Pago_atiempo                                  0.00                       0.02
#
#                                creditos_sectorCooperativo  \
# saldo_total                                          0.09
# saldo_principal                                      0.09
# saldo_mora_codeudor                                 -0.00
# creditos_sectorFinanciero                           -0.02
# creditos_sectorCooperativo                           1.00
# creditos_sectorReal                                  0.06
# promedio_ingresos_datacredito                        0.01
# Pago_atiempo                                         0.02
#
#                                creditos_sectorReal  \
# saldo_total                                   0.07
# saldo_principal                               0.09
# saldo_mora_codeudor                          -0.00
# creditos_sectorFinanciero                     0.07
# creditos_sectorCooperativo                    0.06
# creditos_sectorReal                           1.00
# promedio_ingresos_datacredito                -0.04
# Pago_atiempo                                 -0.02
#
#                                promedio_ingresos_datacredito  Pago_atiempo
# saldo_total                                             0.21          0.01
# saldo_principal                                         0.27          0.01
# saldo_mora_codeudor                                    -0.00          0.00
# creditos_sectorFinanciero                               0.22          0.02
# creditos_sectorCooperativo                              0.01          0.02
# creditos_sectorReal                                    -0.04         -0.02
# promedio_ingresos_datacredito                           1.00          0.04
# Pago_atiempo                                            0.04          1.00

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
plt.imshow(corr_matrix)
plt.colorbar()
plt.xticks(range(len(corr_matrix.columns)), corr_matrix.columns, rotation=90)
plt.yticks(range(len(corr_matrix.columns)), corr_matrix.columns)
plt.title("Matriz de correlación - Análisis Multivariable")
plt.show()
